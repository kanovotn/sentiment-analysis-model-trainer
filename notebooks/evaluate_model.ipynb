# %% [markdown]
# <a href="https://colab.research.google.com/github/kanovotn/sentiment-analysis-model-trainer/blob/master/notebooks/evaluate_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get evaluation metrics (accuracy, recall, precision, f1) on specified dataset

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 18.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# ...

# %%
from datasets import load_dataset
from evaluate import evaluator
import evaluate

# %%
data = load_dataset("stanfordnlp/imdb", split="test").shuffle(seed=42).select(range(1000))
task_evaluator = evaluator("text-classification")

eval_results = task_evaluator.compute(
      model_or_pipeline="lyrisha/bert-finetuned-imdb-sentiment",
      data=data,
      metric=evaluate.combine(["f1"]),
      label_mapping={"NEGATIVE": 0, "POSITIVE": 1}
    )

print(eval_results)
# Out:
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# {'f1': 0.9204665959703076, 'total_time_in_seconds': 19.230660897999996, 'samples_per_second': 52.00029293345819, 'latency_in_seconds': 0.019230660897999997}
